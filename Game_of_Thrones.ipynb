# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("albenft/game-of-thrones-script-all-seasons")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|████████████████████████████████████████| 691k/691k [00:00<00:00, 15.8MB/s]
# Extracting files...
# Path to dataset files: /Users/evelynchu/.cache/kagglehub/datasets/albenft/game-of-thrones-script-all-seasons/versions/1

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

directory = "/Users/evelynchu/.cache/kagglehub/datasets/albenft/game-of-thrones-script-all-seasons/versions/1"
print("Files in directory:")
print(os.listdir(directory))
# Out:
# Files in directory:
# ['Game_of_Thrones_Script.csv']

# %%
# Read the csv file 
import pandas as pd
import os

directory = "/Users/evelynchu/.cache/kagglehub/datasets/albenft/game-of-thrones-script-all-seasons/versions/1"
Game_of_Thrones_text = os.path.join(directory, "Game_of_Thrones_Script.csv")

file = pd.read_csv(Game_of_Thrones_text)
print(file)
# Out:
#       Release Date    Season    Episode     Episode Title              Name  \
# 0       2011-04-17  Season 1  Episode 1  Winter is Coming      waymar royce
# 1       2011-04-17  Season 1  Episode 1  Winter is Coming              will
# 2       2011-04-17  Season 1  Episode 1  Winter is Coming      waymar royce
# 3       2011-04-17  Season 1  Episode 1  Winter is Coming              will
# 4       2011-04-17  Season 1  Episode 1  Winter is Coming             gared
# ...            ...       ...        ...               ...               ...
# 23906   2019-05-19  Season 8  Episode 6   The Iron Throne           brienne
# 23907   2019-05-19  Season 8  Episode 6   The Iron Throne             bronn
# 23908   2019-05-19  Season 8  Episode 6   The Iron Throne  tyrion lannister
# 23909   2019-05-19  Season 8  Episode 6   The Iron Throne               man
# 23910   2019-05-19  Season 8  Episode 6   The Iron Throne               all
#
#                                                 Sentence
# ...

# %% [markdown]
# ## Main Title

# %% [markdown]
# ## The Rains of Castamere

# %% [markdown]
# S2 E1 The North Remembers

# %% [markdown]
# Tyrion Lannister hums 'The Rains of Castamere' as he walks into the small council meeting.
# After humming briefly, Tyrion sumply greets the council members and begins speaking.
# [Background] Emphasizing the power of House Lannister and Tyrion's confidence.

# %% [markdown]
# S2 E9 Blackwater: reinforce the power and merciless dominance of House Lannister over those who defy them.

# %% [markdown]
# 1. Bronn and the Lannister soldiers singing

# %%
# Select scripts
S2E9 = file[(file['Season'] == 'Season 2') & 
(file['Episode'] == 'Episode 9')].reset_index(drop=True)

# Target 'The Rains of Castamere'
keywords_rain1 = ['who are you', 'proud lord said']

for word in keywords_rain1:
    print(f"---{word}---")
    display(S2E9[S2E9['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---who are you---
#     Release Date    Season    Episode Episode Title         Name  \
# 355   2012-05-27  Season 2  Episode 9    Blackwater  male singer
#
#                                               Sentence
# 355  And who are you," the proud lord said / "That ...
# ---proud lord said---
#     Release Date    Season    Episode Episode Title         Name  \
# 355   2012-05-27  Season 2  Episode 9    Blackwater  male singer
#
#                                               Sentence
# 355  And who are you," the proud lord said / "That ...

# %% [markdown]
# 2. End credits performanceed by the band The National

# %%
from IPython.display import display
display(S2E9)
# Out:
#     Release Date    Season    Episode Episode Title               Name  \
# 0     2012-05-27  Season 2  Episode 9    Blackwater            matthos
# 1     2012-05-27  Season 2  Episode 9    Blackwater              davos
# 2     2012-05-27  Season 2  Episode 9    Blackwater            matthos
# 3     2012-05-27  Season 2  Episode 9    Blackwater              davos
# 4     2012-05-27  Season 2  Episode 9    Blackwater            matthos
# ..           ...       ...        ...           ...                ...
# 351   2012-05-27  Season 2  Episode 9    Blackwater  stannis baratheon
# 352   2012-05-27  Season 2  Episode 9    Blackwater  stannis baratheon
# 353   2012-05-27  Season 2  Episode 9    Blackwater   cersei lannister
# 354   2012-05-27  Season 2  Episode 9    Blackwater    tywin lannister
# 355   2012-05-27  Season 2  Episode 9    Blackwater        male singer
#
#                                               Sentence
# 0                    That's it. The tide's against us.
# ...

# %% [markdown]
# S3 E8：Second Sons

# %%
# Select scripts
S3E8 = file[(file['Season'] == 'Season 3') & 
(file['Episode'] == 'Episode 8')].reset_index(drop=True)

# %%
# Lock the starting of the song 'The Rains of Castamere'
keywords_rain2s = ['radiant', 'your grace']

for word in keywords_rain2s:
    print(f"---{word}---")
    display(S3E8[S3E8['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---radiant---
#     Release Date    Season    Episode Episode Title              Name  \
# 136   2013-05-19  Season 3  Episode 8   Second Sons   margaery tyrell
# 137   2013-05-19  Season 3  Episode 8   Second Sons  cersei lannister
#
#                           Sentence
# 136  You look radiant, Your Grace.
# 137          Radiant? Why radiant?
# ---your grace---
#     Release Date    Season    Episode Episode Title              Name  \
# 22    2013-05-19  Season 3  Episode 8   Second Sons         barristan
# 29    2013-05-19  Season 3  Episode 8   Second Sons         barristan
# 38    2013-05-19  Season 3  Episode 8   Second Sons         barristan
# 63    2013-05-19  Season 3  Episode 8   Second Sons         barristan
# 75    2013-05-19  Season 3  Episode 8   Second Sons             davos
# 89    2013-05-19  Season 3  Episode 8   Second Sons             davos
# 95    2013-05-19  Season 3  Episode 8   Second Sons             davos
# ...

# %%
# Lock the end of the song 'The Rains of Castamere'
keywords_rain2e = ['gone', 'strangled', 'sleep']

for word in keywords_rain2e:
    print(f"---{word}---")
    display(S3E8[S3E8['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---gone---
#     Release Date    Season    Episode Episode Title               Name  \
# 83    2013-05-19  Season 3  Episode 8   Second Sons              davos
# 148   2013-05-19  Season 3  Episode 8   Second Sons    margaery tyrell
# 149   2013-05-19  Season 3  Episode 8   Second Sons   cersei lannister
# 153   2013-05-19  Season 3  Episode 8   Second Sons  joffrey lannister
#
#                                               Sentence
# 83                      I didn't know she'd been gone.
# 148                                              Gone.
# 149  Gone. A gentle word. Why not say slaughtered? ...
# 153  Your father's gone. As the father of the realm...
# ---strangled---
#     Release Date    Season    Episode Episode Title              Name  \
# 151   2013-05-19  Season 3  Episode 8   Second Sons  cersei lannister
#
#                                               Sentence
# 151  If you ever call me sister again, I'll have yo...
# ---sleep---
# ...

# %%
# Select scripts
S3E9 = file[(file['Season'] == 'Season 3') & 
(file['Episode'] == 'Episode 9')].reset_index(drop=True)

# %%
from IPython.display import display
display(S3E9)
# Out:
#     Release Date    Season    Episode           Episode Title           Name  \
# 0     2013-06-02  Season 3  Episode 9  The Rains of Castamere  catelyn stark
# 1     2013-06-02  Season 3  Episode 9  The Rains of Castamere     robb stark
# 2     2013-06-02  Season 3  Episode 9  The Rains of Castamere  catelyn stark
# 3     2013-06-02  Season 3  Episode 9  The Rains of Castamere     robb stark
# 4     2013-06-02  Season 3  Episode 9  The Rains of Castamere  catelyn stark
# ..           ...       ...        ...                     ...            ...
# 291   2013-06-02  Season 3  Episode 9  The Rains of Castamere         walder
# 292   2013-06-02  Season 3  Episode 9  The Rains of Castamere  catelyn stark
# 293   2013-06-02  Season 3  Episode 9  The Rains of Castamere         walder
# 294   2013-06-02  Season 3  Episode 9  The Rains of Castamere     robb stark
# 295   2013-06-02  Season 3  Episode 9  The Rains of Castamere          roose
#
# ...

# %%
# Lock the starting of the song 'The Rains of Castamere'
keywords_rainS = ['duties', 'wine', 'music', 'wedding gift']

for word in keywords_rainS:
    print(f"---{word}---")
    display(S3E9[S3E9['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---duties---
#     Release Date    Season    Episode           Episode Title    Name  \
# 280   2013-06-02  Season 3  Episode 9  The Rains of Castamere  walder
#
#                                   Sentence
# 280  I feel I've been remiss in my duties.
# ---wine---
#     Release Date    Season    Episode           Episode Title    Name  \
# 33    2013-06-02  Season 3  Episode 9  The Rains of Castamere  walder
# 281   2013-06-02  Season 3  Episode 9  The Rains of Castamere  walder
#
#                                               Sentence
# 33   Well, let's get ready. The wine will flow red ...
# 281  I've given you meat and wine and music but I h...
# ---music---
#     Release Date    Season    Episode           Episode Title    Name  \
# 33    2013-06-02  Season 3  Episode 9  The Rains of Castamere  walder
# 281   2013-06-02  Season 3  Episode 9  The Rains of Castamere  walder
#
#                                               Sentence
# ...

# %%
# Lock the end of the song 'The Rains of Castamere'
keywords_rainE = ['lord walder', 'first son', 'swear', 'vengeance']

for word in keywords_rainE:
    print(f"---{word}---")
    display(S3E9[S3E9['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---lord walder---
#     Release Date    Season    Episode           Episode Title           Name  \
# 243   2013-06-02  Season 3  Episode 9  The Rains of Castamere          roose
# 257   2013-06-02  Season 3  Episode 9  The Rains of Castamere     robb stark
# 288   2013-06-02  Season 3  Episode 9  The Rains of Castamere  catelyn stark
#
#                                               Sentence
# 243  Aye. Lord Walder let me choose any of his gran...
# 257  If you think the time is right, Lord Walder, b...
# 288  Lord Walder! Lord Walder, enough! Let it end! ...
# ---first son---
#     Release Date    Season    Episode           Episode Title           Name  \
# 288   2013-06-02  Season 3  Episode 9  The Rains of Castamere  catelyn stark
#
#                                               Sentence
# 288  Lord Walder! Lord Walder, enough! Let it end! ...
# ---swear---
#     Release Date    Season    Episode           Episode Title           Name  \
# ...

# %%
start_index = 281
end_index = 288
rains_segment = S3E9.loc[start_index:end_index]
display(rains_segment)
# Out:
#     Release Date    Season    Episode           Episode Title            Name  \
# 281   2013-06-02  Season 3  Episode 9  The Rains of Castamere          walder
# 282   2013-06-02  Season 3  Episode 9  The Rains of Castamere   catelyn stark
# 283   2013-06-02  Season 3  Episode 9  The Rains of Castamere             man
# 284   2013-06-02  Season 3  Episode 9  The Rains of Castamere             man
# 285   2013-06-02  Season 3  Episode 9  The Rains of Castamere        frey man
# 286   2013-06-02  Season 3  Episode 9  The Rains of Castamere  sandor clegane
# 287   2013-06-02  Season 3  Episode 9  The Rains of Castamere          walder
# 288   2013-06-02  Season 3  Episode 9  The Rains of Castamere   catelyn stark
#
#                                               Sentence
# 281  I've given you meat and wine and music but I h...
# 282                                              Robb!
# 283          You ready to head home to Winterfell, eh?
# ...

# %%
rains_segment.to_csv("S3E9_rains.csv", index=False)

# %% [markdown]
# S4E2：The Lion and the Rose

# %%
# Select scripts
S4E2 = file[(file['Season'] == 'Season 4') & 
(file['Episode'] == 'Episode 2')].reset_index(drop=True)

from IPython.display import display
display(S4E2)
# Out:
#     Release Date    Season    Episode          Episode Title  \
# 0     2014-04-13  Season 4  Episode 2  The Lion and the Rose
# 1     2014-04-13  Season 4  Episode 2  The Lion and the Rose
# 2     2014-04-13  Season 4  Episode 2  The Lion and the Rose
# 3     2014-04-13  Season 4  Episode 2  The Lion and the Rose
# 4     2014-04-13  Season 4  Episode 2  The Lion and the Rose
# ..           ...       ...        ...                    ...
# 390   2014-04-13  Season 4  Episode 2  The Lion and the Rose
# 391   2014-04-13  Season 4  Episode 2  The Lion and the Rose
# 392   2014-04-13  Season 4  Episode 2  The Lion and the Rose
# 393   2014-04-13  Season 4  Episode 2  The Lion and the Rose
# 394   2014-04-13  Season 4  Episode 2  The Lion and the Rose
#
#                  Name                                           Sentence
# 0       ramsay bolton                               Tansy! Tansy! Tansy!
# 1       ramsay bolton                                      Tansy! Tansy!
# ...

# %%
# Lock the end of the song 'The Rains of Castamere'
keywords_rainS = ['Prince Oberyn', 'Ellaria']

for word in keywords_rainS:
    print(f"---{word}---")
    display(S4E2[S4E2['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---Prince Oberyn---
#     Release Date    Season    Episode          Episode Title  \
# 311   2014-04-13  Season 4  Episode 2  The Lion and the Rose
# 320   2014-04-13  Season 4  Episode 2  The Lion and the Rose
#
#                  Name                                           Sentence
# 311   tywin lannister                                     Prince Oberyn.
# 320  cersei lannister  I suppose you'll never know, Prince Oberyn. It...
# ---Ellaria---
#     Release Date    Season    Episode          Episode Title            Name  \
# 312   2014-04-13  Season 4  Episode 2  The Lion and the Rose  oberyn martell
#
#                                               Sentence
# 312  I don't believe you have met Ellaria. This is ...

# %%
# Lock the end of the song 'The Rains of Castamere'
keywords_rainE = ['royal wedding']

for word in keywords_rainE:
    print(f"---{word}---")
    display(S4E2[S4E2['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---royal wedding---
#     Release Date    Season    Episode          Episode Title  \
# 325   2014-04-13  Season 4  Episode 2  The Lion and the Rose
#
#                   Name                                           Sentence
# 325  joffrey lannister  Everyone, silence! Clear the floor. There's be...

# %% [markdown]
# ## Light of the Seven

# %% [markdown]
# Season 6 Episode 10 The Wings of Winter
# This is the first appearance of Light of the Seven, playede during the pivotal sequence in which Cersei Lannister orchestrates and executes the destruction of the Great Spet of Baelor.
# Piano + 10 mins
#
# Season 8 Episode 5 The Bells
# In this episode, a variation of Light of the Seven is used as Daenerys Targaryen begins her assault on King's Landing, foreshadowing Cersei's downfall.
# It is primarily used to underscore Cersei Lannister's sense of despair as she watches King's Landing being destroyed by Daenerys Targaryen from within the Red Keep.

# %%
# Select full scripts
S6E10 = file[(file['Season'] == 'Season 6') & 
(file['Episode'] == 'Episode 10')].reset_index(drop=True)

# %%
# Lock the start of the song 'Light of the Seven'
keywords_light1s = ["sins", "trial"]

for word in keywords_light1s:
    print(f"---{word}---")
    display(S6E10[S6E10['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---sins---
#    Release Date    Season     Episode        Episode Title   Name  \
# 10   2016-06-26  Season 6  Episode 10  The Winds of Winter  loras
#
#                                              Sentence
# 10  I take full responsibility for my many sins an...
# ---trial---
#    Release Date    Season     Episode        Episode Title              Name  \
# 0    2016-06-26  Season 6  Episode 10  The Winds of Winter         attendant
# 4    2016-06-26  Season 6  Episode 10  The Winds of Winter           sparrow
# 5    2016-06-26  Season 6  Episode 10  The Winds of Winter             loras
# 20   2016-06-26  Season 6  Episode 10  The Winds of Winter  tommen lannister
# 22   2016-06-26  Season 6  Episode 10  The Winds of Winter           sparrow
# 25   2016-06-26  Season 6  Episode 10  The Winds of Winter           sparrow
# 36   2016-06-26  Season 6  Episode 10  The Winds of Winter           sparrow
# 39   2016-06-26  Season 6  Episode 10  The Winds of Winter   margaery tyrell
#
# ...

# %%
# Lock the end of the song 'Light of the Seven'
keywords_light1e = ['confess']

for word in keywords_light1e:
    print(f"---{word}---")
    display(S6E10[S6E10['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---confess---
#    Release Date    Season     Episode        Episode Title              Name  \
# 5    2016-06-26  Season 6  Episode 10  The Winds of Winter             loras
# 6    2016-06-26  Season 6  Episode 10  The Winds of Winter           sparrow
# 44   2016-06-26  Season 6  Episode 10  The Winds of Winter  cersei lannister
# 46   2016-06-26  Season 6  Episode 10  The Winds of Winter  cersei lannister
# 47   2016-06-26  Season 6  Episode 10  The Winds of Winter  cersei lannister
#
#                                              Sentence
# 5   There'll be no need for a trial. I confess bef...
# 6             To which crimes will you be confessing?
# 44                                  Confess. Confess.
# 46                                           Confess.
# 47  Confess. It felt good. Beating me, starving me...

# %% [markdown]
# ## Jenny of Oldstones

# %%
# Select full scripts
S8E2 = file[(file['Season'] == 'Season 8') & 
(file['Episode'] == 'Episode 2')].reset_index(drop=True)

# %%
from IPython.display import display
display(S8E2)
# Out:
#     Release Date    Season    Episode                   Episode Title  \
# 0     2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
# 1     2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
# 2     2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
# 3     2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
# 4     2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
# ..           ...       ...        ...                             ...
# 400   2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
# 401   2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
# 402   2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
# 403   2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
# 404   2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
#
#                    Name                                           Sentence
# ...

# %%
# Lock the starting of the song 'Light of the Seven'
keywords_jennyS = ['podrick', 'jenny']

for word in keywords_jennyS:
    print(f"---{word}---")
    display(S8E2[S8E2['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---podrick---
# Empty DataFrame
# Columns: [Release Date, Season, Episode, Episode Title, Name, Sentence]
# Index: []
# ---jenny---
#     Release Date    Season    Episode                   Episode Title  \
# 383   2019-04-21  Season 8  Episode 2  A Knight of the Seven Kingdoms
#
#         Name                                           Sentence
# 383  podrick  High in the halls of the kings who are gone, J...

# %%
# Lock the end of the song 'Light of the Seven'
keywords_jennyE = ['campfire', 'silence']

for word in keywords_jennyE:
    print(f"---{word}---")
    display(S8E2[S8E2['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---campfire---
# Empty DataFrame
# Columns: [Release Date, Season, Episode, Episode Title, Name, Sentence]
# Index: []
# ---silence---
# Empty DataFrame
# Columns: [Release Date, Season, Episode, Episode Title, Name, Sentence]
# Index: []

# %% [markdown]
# ## The Night King

# %%
# Select full scripts
S8E3 = file[(file['Season'] == 'Season 8') & 
(file['Episode'] == 'Episode 3')].reset_index(drop=True)

# %%
from IPython.display import display
display(S8E3)
# Out:
#     Release Date    Season    Episode   Episode Title                Name  \
# 0     2019-04-28  Season 8  Episode 3  The Long Night            northman
# 1     2019-04-28  Season 8  Episode 3  The Long Night            northman
# 2     2019-04-28  Season 8  Episode 3  The Long Night            northman
# 3     2019-04-28  Season 8  Episode 3  The Long Night            northman
# 4     2019-04-28  Season 8  Episode 3  The Long Night             soldier
# ..           ...       ...        ...             ...                 ...
# 150   2019-04-28  Season 8  Episode 3  The Long Night  daenerys targaryen
# 151   2019-04-28  Season 8  Episode 3  The Long Night          bran stark
# 152   2019-04-28  Season 8  Episode 3  The Long Night          bran stark
# 153   2019-04-28  Season 8  Episode 3  The Long Night          bran stark
# 154   2019-04-28  Season 8  Episode 3  The Long Night       jorah mormont
#
#                     Sentence
# 0                        Oi!
# ...

# %%
# Lock the starting of the song 'Light of the Seven'
keywords_nightS = ['theon', 'godswood']

for word in keywords_nightS:
    print(f"---{word}---")
    display(S8E3[S8E3['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---theon---
#     Release Date    Season    Episode   Episode Title        Name Sentence
# 151   2019-04-28  Season 8  Episode 3  The Long Night  bran stark   Theon.
# ---godswood---
# Empty DataFrame
# Columns: [Release Date, Season, Episode, Episode Title, Name, Sentence]
# Index: []

# %%
# Lock the end of the song 'Light of the Seven'
keywords_nightE = ['arya', 'kill', 'shatter']

for word in keywords_nightE:
    print(f"---{word}---")
    display(S8E3[S8E3['Sentence'].str.contains(word, case=False, na=False)])
# Out:
# ---arya---
# Empty DataFrame
# Columns: [Release Date, Season, Episode, Episode Title, Name, Sentence]
# Index: []
# ---kill---
# Empty DataFrame
# Columns: [Release Date, Season, Episode, Episode Title, Name, Sentence]
# Index: []
# ---shatter---
# Empty DataFrame
# Columns: [Release Date, Season, Episode, Episode Title, Name, Sentence]
# Index: []
